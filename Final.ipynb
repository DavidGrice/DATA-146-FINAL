# %%
# Prakrit Shukla and David Grice

# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as ss
import random
import math

# %%
def OR_CI(a,b,c,d,alpha):
    est = math.log(a*d/(b*c))
    stderr = ((1/a) + (1/b) + (1/c) + (1/d))**0.5
    z = ss.norm.ppf(1-alpha/2)
    low = est - z*stderr
    high = est + z*stderr
    return math.e**low, math.e**high

# %%
# First 13 questions dealing with Earthquake
earthQuake = pd.read_csv("earth_orig_dropped.csv")

# %%
new_earthQuake = earthQuake[["Worried", "Worried_Big_One", "Big_One_Lifetime", "Preparations"]]
new_earthQuake
# Out:
#                 Worried     Worried_Big_One Big_One_Lifetime Preparations
# 0    Not at all worried      Not so worried               No           No
# 1      Somewhat worried        Very worried               No           No
# 2        Not so worried    Somewhat worried               No           No
# 3        Not so worried      Not so worried               No           No
# 4        Not so worried      Not so worried              Yes           No
# 5    Not at all worried  Not at all worried               No           No
# 6    Not at all worried  Not at all worried               No           No
# 7    Not at all worried  Not at all worried               No           No
# 8    Not at all worried  Not at all worried               No           No
# 9    Not at all worried      Not so worried               No           No
# 10   Not at all worried  Not at all worried               No           No
# 11     Somewhat worried        Very worried              Yes           No
# 12       Not so worried      Not so worried               No           No
# 13       Not so worried    Somewhat worried              Yes           No
# 14   Not at all worried  Not at all worried               No           No
# 15       Not so worried    Somewhat worried              Yes           No
# 16       Not so worried      Not so worried              Yes           No
# 17         Very worried   Extremely worried              Yes           No
# 18   Not at all worried  Not at all worried               No           No
# 19   Not at all worried  Not at all worried               No           No
# 20   Not at all worried  Not at all worried               No           No
# 21       Not so worried        Very worried              Yes           No
# 22   Not at all worried  Not at all worried              Yes           No
# 23   Not at all worried  Not at all worried               No           No
# 24   Not at all worried  Not at all worried               No           No
# 25     Somewhat worried        Very worried               No           No
# 26       Not so worried      Not so worried               No           No
# 27       Not so worried    Somewhat worried              Yes           No
# 28     Somewhat worried    Somewhat worried               No           No
# 29     Somewhat worried    Somewhat worried              Yes          Yes
# ..                  ...                 ...              ...          ...
# 948  Not at all worried      Not so worried               No           No
# 949  Not at all worried  Not at all worried               No           No
# 950   Extremely worried   Extremely worried              Yes           No
# 951      Not so worried      Not so worried              Yes          Yes
# 952  Not at all worried  Not at all worried               No           No
# 953  Not at all worried      Not so worried               No          Yes
# 954  Not at all worried  Not at all worried               No           No
# 955   Extremely worried   Extremely worried              Yes          Yes
# 956      Not so worried      Not so worried              Yes           No
# 957      Not so worried      Not so worried               No           No
# 958    Somewhat worried        Very worried              Yes           No
# 959      Not so worried      Not so worried              Yes           No
# 960  Not at all worried  Not at all worried               No           No
# 961      Not so worried  Not at all worried               No           No
# 962  Not at all worried  Not at all worried               No           No
# 963      Not so worried    Somewhat worried               No           No
# 964      Not so worried      Not so worried              Yes           No
# 965  Not at all worried  Not at all worried               No           No
# 966  Not at all worried      Not so worried               No           No
# 967      Not so worried      Not so worried              Yes           No
# 968  Not at all worried  Not at all worried               No           No
# 969    Somewhat worried    Somewhat worried              Yes          Yes
# 970  Not at all worried  Not at all worried               No           No
# 971      Not so worried      Not so worried               No          Yes
# 972  Not at all worried  Not at all worried               No           No
# 973  Not at all worried  Not at all worried               No           No
# 974  Not at all worried  Not at all worried               No           No
# 975      Not so worried    Somewhat worried               No          Yes
# 976      Not so worried   Extremely worried               No           No
# 977  Not at all worried      Not so worried               No           No
#
# [978 rows x 4 columns]

# %%
new_earthQuake["Worried"]
# Out:
# 0      Not at all worried
# 1        Somewhat worried
# 2          Not so worried
# 3          Not so worried
# 4          Not so worried
# 5      Not at all worried
# 6      Not at all worried
# 7      Not at all worried
# 8      Not at all worried
# 9      Not at all worried
# 10     Not at all worried
# 11       Somewhat worried
# 12         Not so worried
# 13         Not so worried
# 14     Not at all worried
# 15         Not so worried
# 16         Not so worried
# 17           Very worried
# 18     Not at all worried
# 19     Not at all worried
# 20     Not at all worried
# 21         Not so worried
# 22     Not at all worried
# 23     Not at all worried
# 24     Not at all worried
# 25       Somewhat worried
# 26         Not so worried
# 27         Not so worried
# 28       Somewhat worried
# 29       Somewhat worried
#               ...
# 948    Not at all worried
# 949    Not at all worried
# 950     Extremely worried
# 951        Not so worried
# 952    Not at all worried
# 953    Not at all worried
# 954    Not at all worried
# 955     Extremely worried
# 956        Not so worried
# 957        Not so worried
# 958      Somewhat worried
# 959        Not so worried
# 960    Not at all worried
# 961        Not so worried
# 962    Not at all worried
# 963        Not so worried
# 964        Not so worried
# 965    Not at all worried
# 966    Not at all worried
# 967        Not so worried
# 968    Not at all worried
# 969      Somewhat worried
# 970    Not at all worried
# 971        Not so worried
# 972    Not at all worried
# 973    Not at all worried
# 974    Not at all worried
# 975        Not so worried
# 976        Not so worried
# 977    Not at all worried
# Name: Worried, Length: 978, dtype: object

# %%
earthQuake
# Out:
#      Unnamed: 0             Worried     Worried_Big_One Big_One_Lifetime  \
# 0             0  Not at all worried      Not so worried               No
# 1             1    Somewhat worried        Very worried               No
# 2             2      Not so worried    Somewhat worried               No
# 3             3      Not so worried      Not so worried               No
# 4             4      Not so worried      Not so worried              Yes
# 5             5  Not at all worried  Not at all worried               No
# 6             7  Not at all worried  Not at all worried               No
# 7             8  Not at all worried  Not at all worried               No
# 8             9  Not at all worried  Not at all worried               No
# 9            10  Not at all worried      Not so worried               No
# 10           11  Not at all worried  Not at all worried               No
# 11           13    Somewhat worried        Very worried              Yes
# 12           14      Not so worried      Not so worried               No
# 13           15      Not so worried    Somewhat worried              Yes
# 14           16  Not at all worried  Not at all worried               No
# 15           17      Not so worried    Somewhat worried              Yes
# 16           18      Not so worried      Not so worried              Yes
# 17           19        Very worried   Extremely worried              Yes
# 18           20  Not at all worried  Not at all worried               No
# 19           21  Not at all worried  Not at all worried               No
# 20           22  Not at all worried  Not at all worried               No
# 21           23      Not so worried        Very worried              Yes
# 22           24  Not at all worried  Not at all worried              Yes
# 23           26  Not at all worried  Not at all worried               No
# 24           27  Not at all worried  Not at all worried               No
# 25           28    Somewhat worried        Very worried               No
# 26           29      Not so worried      Not so worried               No
# 27           30      Not so worried    Somewhat worried              Yes
# 28           31    Somewhat worried    Somewhat worried               No
# 29           34    Somewhat worried    Somewhat worried              Yes
# ..          ...                 ...                 ...              ...
# 948         980  Not at all worried      Not so worried               No
# 949         981  Not at all worried  Not at all worried               No
# 950         982   Extremely worried   Extremely worried              Yes
# 951         983      Not so worried      Not so worried              Yes
# 952         985  Not at all worried  Not at all worried               No
# 953         986  Not at all worried      Not so worried               No
# 954         987  Not at all worried  Not at all worried               No
# 955         988   Extremely worried   Extremely worried              Yes
# 956         989      Not so worried      Not so worried              Yes
# 957         990      Not so worried      Not so worried               No
# 958         991    Somewhat worried        Very worried              Yes
# 959         993      Not so worried      Not so worried              Yes
# 960         994  Not at all worried  Not at all worried               No
# 961         995      Not so worried  Not at all worried               No
# 962         996  Not at all worried  Not at all worried               No
# 963         997      Not so worried    Somewhat worried               No
# 964         998      Not so worried      Not so worried              Yes
# 965         999  Not at all worried  Not at all worried               No
# 966        1000  Not at all worried      Not so worried               No
# 967        1001      Not so worried      Not so worried              Yes
# 968        1002  Not at all worried  Not at all worried               No
# 969        1003    Somewhat worried    Somewhat worried              Yes
# 970        1004  Not at all worried  Not at all worried               No
# 971        1005      Not so worried      Not so worried               No
# 972        1006  Not at all worried  Not at all worried               No
# 973        1007  Not at all worried  Not at all worried               No
# 974        1008  Not at all worried  Not at all worried               No
# 975        1009      Not so worried    Somewhat worried               No
# 976        1010      Not so worried   Extremely worried               No
# 977        1011  Not at all worried      Not so worried               No
#
#                       Experience Preparations          San Andreas  \
# 0    Yes, one or more minor ones           No    Somewhat familiar
# 1    Yes, one or more minor ones           No  Not at all familiar
# 2    Yes, one or more minor ones           No        Very familiar
# 3    Yes, one or more minor ones           No        Very familiar
# 4    Yes, one or more minor ones           No    Somewhat familiar
# 5    Yes, one or more minor ones           No        Very familiar
# 6                             No           No      Not so familiar
# 7    Yes, one or more minor ones           No        Very familiar
# 8                             No           No  Not at all familiar
# 9    Yes, one or more major ones           No    Somewhat familiar
# 10                            No           No   Extremely familiar
# 11   Yes, one or more minor ones           No    Somewhat familiar
# 12                            No           No        Very familiar
# 13   Yes, one or more minor ones           No    Somewhat familiar
# 14                            No           No    Somewhat familiar
# 15   Yes, one or more minor ones           No      Not so familiar
# 16   Yes, one or more minor ones           No    Somewhat familiar
# 17   Yes, one or more minor ones           No    Somewhat familiar
# 18                            No           No    Somewhat familiar
# 19                            No           No    Somewhat familiar
# 20   Yes, one or more minor ones           No  Not at all familiar
# 21   Yes, one or more minor ones           No        Very familiar
# 22   Yes, one or more minor ones           No    Somewhat familiar
# 23   Yes, one or more minor ones           No        Very familiar
# 24   Yes, one or more minor ones           No   Extremely familiar
# 25                            No           No        Very familiar
# 26                            No           No      Not so familiar
# 27   Yes, one or more minor ones           No      Not so familiar
# 28   Yes, one or more minor ones           No  Not at all familiar
# 29   Yes, one or more minor ones          Yes    Somewhat familiar
# ..                           ...          ...                  ...
# 948  Yes, one or more major ones           No   Extremely familiar
# 949  Yes, one or more minor ones           No    Somewhat familiar
# 950  Yes, one or more minor ones           No  Not at all familiar
# 951  Yes, one or more major ones          Yes   Extremely familiar
# 952  Yes, one or more minor ones           No        Very familiar
# 953                           No          Yes      Not so familiar
# 954                           No           No   Extremely familiar
# 955  Yes, one or more major ones          Yes   Extremely familiar
# 956                           No           No    Somewhat familiar
# 957  Yes, one or more minor ones           No   Extremely familiar
# 958  Yes, one or more minor ones           No   Extremely familiar
# 959  Yes, one or more minor ones           No        Very familiar
# 960  Yes, one or more minor ones           No        Very familiar
# 961  Yes, one or more minor ones           No    Somewhat familiar
# 962                           No           No        Very familiar
# 963  Yes, one or more minor ones           No      Not so familiar
# 964  Yes, one or more minor ones           No        Very familiar
# 965                           No           No  Not at all familiar
# 966                           No           No    Somewhat familiar
# 967  Yes, one or more major ones           No   Extremely familiar
# 968  Yes, one or more major ones           No        Very familiar
# 969  Yes, one or more minor ones          Yes    Somewhat familiar
# 970                           No           No  Not at all familiar
# 971                           No          Yes    Somewhat familiar
# 972  Yes, one or more minor ones           No        Very familiar
# 973                           No           No    Somewhat familiar
# 974  Yes, one or more minor ones           No        Very familiar
# 975  Yes, one or more major ones          Yes   Extremely familiar
# 976  Yes, one or more minor ones           No    Somewhat familiar
# 977                           No           No    Somewhat familiar
#
#              Yellowstone      Age  Gender                Income  \
# 0        Not so familiar  18 - 29    Male  Prefer not to answer
# 1    Not at all familiar  18 - 29    Male    $75,000 to $99,999
# 2      Somewhat familiar  18 - 29    Male    $10,000 to $24,999
# 3        Not so familiar  18 - 29    Male    $25,000 to $49,999
# 4     Extremely familiar  18 - 29    Male       $200,000 and up
# 5        Not so familiar  18 - 29    Male    $25,000 to $49,999
# 6    Not at all familiar  18 - 29    Male  Prefer not to answer
# 7      Somewhat familiar  18 - 29    Male  Prefer not to answer
# 8        Not so familiar  18 - 29    Male    $10,000 to $24,999
# 9        Not so familiar  18 - 29    Male    $50,000 to $74,999
# 10    Extremely familiar  18 - 29    Male    $25,000 to $49,999
# 11       Not so familiar  18 - 29    Male          $0 to $9,999
# 12     Somewhat familiar  18 - 29    Male  $100,000 to $124,999
# 13     Somewhat familiar  18 - 29    Male    $50,000 to $74,999
# 14     Somewhat familiar  18 - 29    Male    $25,000 to $49,999
# 15     Somewhat familiar  18 - 29    Male    $75,000 to $99,999
# 16     Somewhat familiar  30 - 44    Male    $25,000 to $49,999
# 17       Not so familiar  30 - 44    Male    $10,000 to $24,999
# 18     Somewhat familiar  18 - 29    Male    $50,000 to $74,999
# 19         Very familiar  30 - 44    Male    $75,000 to $99,999
# 20   Not at all familiar  18 - 29    Male    $50,000 to $74,999
# 21         Very familiar  18 - 29    Male    $75,000 to $99,999
# 22     Somewhat familiar  30 - 44    Male    $25,000 to $49,999
# 23         Very familiar  30 - 44    Male    $75,000 to $99,999
# 24       Not so familiar  30 - 44    Male    $75,000 to $99,999
# 25     Somewhat familiar  30 - 44    Male    $25,000 to $49,999
# 26   Not at all familiar  18 - 29    Male    $25,000 to $49,999
# 27       Not so familiar  18 - 29    Male    $25,000 to $49,999
# 28   Not at all familiar  18 - 29    Male          $0 to $9,999
# 29     Somewhat familiar  30 - 44    Male  $100,000 to $124,999
# ..                   ...      ...     ...                   ...
# 948   Extremely familiar       60    Male    $75,000 to $99,999
# 949        Very familiar  18 - 29  Female    $10,000 to $24,999
# 950  Not at all familiar  18 - 29  Female    $10,000 to $24,999
# 951  Not at all familiar       60    Male       $200,000 and up
# 952    Somewhat familiar  45 - 59    Male    $25,000 to $49,999
# 953      Not so familiar  30 - 44  Female          $0 to $9,999
# 954    Somewhat familiar  45 - 59  Female    $50,000 to $74,999
# 955   Extremely familiar  30 - 44  Female          $0 to $9,999
# 956      Not so familiar  30 - 44  Female          $0 to $9,999
# 957   Extremely familiar       60  Female    $10,000 to $24,999
# 958      Not so familiar  30 - 44  Female  Prefer not to answer
# 959    Somewhat familiar  45 - 59    Male    $75,000 to $99,999
# 960  Not at all familiar  30 - 44  Female    $25,000 to $49,999
# 961  Not at all familiar  30 - 44  Female    $75,000 to $99,999
# 962      Not so familiar  45 - 59  Female  $100,000 to $124,999
# 963      Not so familiar  45 - 59    Male          $0 to $9,999
# 964  Not at all familiar       60  Female    $25,000 to $49,999
# 965    Somewhat familiar  30 - 44  Female    $50,000 to $74,999
# 966  Not at all familiar       60  Female    $50,000 to $74,999
# 967    Somewhat familiar       60  Female    $75,000 to $99,999
# 968    Somewhat familiar       60    Male    $75,000 to $99,999
# 969    Somewhat familiar  45 - 59    Male    $50,000 to $74,999
# 970  Not at all familiar  18 - 29  Female    $10,000 to $24,999
# 971    Somewhat familiar       60  Female       $200,000 and up
# 972    Somewhat familiar  45 - 59    Male    $75,000 to $99,999
# 973    Somewhat familiar       60  Female  Prefer not to answer
# 974      Not so familiar       60    Male  Prefer not to answer
# 975    Somewhat familiar       60  Female    $50,000 to $74,999
# 976    Somewhat familiar  30 - 44  Female  Prefer not to answer
# 977    Somewhat familiar  30 - 44  Female    $50,000 to $74,999
#
#                  Region
# 0           New England
# 1    East North Central
# 2               Pacific
# 3    West South Central
# 4       Middle Atlantic
# 5    East North Central
# 6        South Atlantic
# 7    East North Central
# 8    East North Central
# 9    West North Central
# 10   East South Central
# 11              Pacific
# 12          New England
# 13   East North Central
# 14   East North Central
# 15   East North Central
# 16              Pacific
# 17              Pacific
# 18             Mountain
# 19       South Atlantic
# 20      Middle Atlantic
# 21      Middle Atlantic
# 22   East North Central
# 23   East North Central
# 24      Middle Atlantic
# 25   East North Central
# 26       South Atlantic
# 27   East North Central
# 28   East North Central
# 29   East South Central
# ..                  ...
# 948  West South Central
# 949  West North Central
# 950      South Atlantic
# 951             Pacific
# 952             Pacific
# 953  East North Central
# 954      South Atlantic
# 955             Pacific
# 956  East North Central
# 957         New England
# 958             Pacific
# 959         New England
# 960  East South Central
# 961      South Atlantic
# 962     Middle Atlantic
# 963             Pacific
# 964  East North Central
# 965         New England
# 966     Middle Atlantic
# 967      South Atlantic
# 968            Mountain
# 969             Pacific
# 970  East North Central
# 971  West North Central
# 972  East North Central
# 973         New England
# 974             Pacific
# 975             Pacific
# 976     Middle Atlantic
# 977  East North Central
#
# [978 rows x 12 columns]

# %%
earthQuake["Region"].describe()
# Out:
# count         978
# unique          9
# top       Pacific
# freq          206
# Name: Region, dtype: object

# %%
df = pd.DataFrame(earthQuake, columns=['Yellowstone', 'Worried_Big_One'])
#df=pandas.DataFrame(data, columns=['Fruit', 'Shop', 'Price'])
#df.pivot(index='Yellowstone', columns='Worried_Big_One')

# %%
#table_1 = pd.crosstab(earthQuake["Yellowstone"], earthQuake["Woried_Big_One"])
table_1 = pd.crosstab(earthQuake['Yellowstone'], earthQuake['Worried_Big_One'])

columnsTitles = (['Not at all worried','Not so worried','Somewhat worried','Very worried','Extremely worried'])
table_1 = table_1.reindex(['Extremely familiar','Very familiar','Somewhat familiar','Not so familiar', 'Not at all familiar'], columns = columnsTitles)
#df.reindex(columns=columnsTitles)
table_1
# Out:
# Worried_Big_One      Not at all worried  Not so worried  Somewhat worried  \
# Yellowstone
# Extremely familiar                   32              26                15
# Very familiar                        38              37                41
# Somewhat familiar                    96              77                70
# Not so familiar                      57              91                38
# Not at all familiar                 106              72                50
#
# Worried_Big_One      Very worried  Extremely worried
# Yellowstone
# Extremely familiar              7                 13
# Very familiar                  20                  3
# Somewhat familiar              19                 11
# Not so familiar                12                 13
# Not at all familiar            13                 21

# %%
sns.heatmap(table_1, annot = True, cmap = 'BuPu')
#xticklabels=['Not at all worried','Not so worried','Somewhat worried',\
#                                                'Very worried','Extremely worried'], yticklabels=['Extremely familiar','Very familiar','Somewhat familiar','Not so familiar', 'Not at all familiar']
plt.xticks(rotation = 45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5]), <a list of 5 Text xticklabel objects>)

# %%
ss.contingency.chi2_contingency(table_1)
# Out:
# (58.852791476878956,
#  8.157722463767748e-07,
#  16,
#  array([[ 5.8006135 , 31.28527607, 28.81288344, 20.34969325,  6.75153374],
#         [16.34151329, 88.13701431, 81.17177914, 57.32924335, 19.0204499 ],
#         [13.1605317 , 70.9805726 , 65.37116564, 46.16973415, 15.31799591],
#         [17.02760736, 91.83742331, 84.5797546 , 59.73619632, 19.8190184 ],
#         [ 8.66973415, 46.7597137 , 43.06441718, 30.41513292, 10.09100204]]))

# %%
# Question 11
table_2 = pd.crosstab(earthQuake['Preparations'], earthQuake['Big_One_Lifetime'])
table_2
# Out:
# Big_One_Lifetime   No  Yes
# Preparations
# No                488  278
# Yes                72  140

# %%
table_2_est = (488*140)/(278*72)
print(table_2_est)
# Out:
# 3.413269384492406

# %%
# Question 14 -> 18 dealing with Drugs
drugs = pd.read_csv("Drugs.txt", sep="\t")

# %%
drugs.head()
# Out:
#    Individual Alcohol Marijuana Cocaine Heroin Opiods Prescriptions
# 0           3      NO       YES      NO     NO     NO            NO
# 1           4      NO        NO      NO     NO     NO            NO
# 2           7      NO        NO      NO     NO     NO           YES
# 3           9      NO        NO      NO    YES     NO            NO
# 4          10     YES        NO      NO     NO     NO            NO

# %%
alcopiod = drugs[["Alcohol", "Opiods"]]

# %%
alcopiod
# Out:
#    Alcohol Opiods
# 0       NO     NO
# 1       NO     NO
# 2       NO     NO
# 3       NO     NO
# 4      YES     NO
# 5       NO    YES
# 6       NO     NO
# 7       NO     NO
# 8       NO    YES
# 9       NO     NO
# 10      NO     NO
# 11      NO     NO
# 12      NO     NO
# 13      NO    YES
# 14      NO     NO
# 15      NO     NO
# 16     YES    YES
# 17     YES     NO
# 18      NO     NO
# 19     YES    YES
# 20     YES    YES
# 21     YES    YES
# 22     YES     NO
# 23     YES     NO
# 24     YES     NO
# 25     YES     NO
# 26     YES     NO
# 27     YES     NO
# 28     YES     NO
# 29     YES     NO
# 30     YES     NO
# 31     YES     NO
# 32     YES     NO
# 33     YES     NO
# 34     YES     NO
# 35      NO     NO
# 36      NO     NO
# 37     YES    YES
# 38     YES     NO
# 39     YES    YES
# 40     YES     NO
# 41     YES     NO
# 42     YES    YES
# 43     YES     NO
# 44     YES     NO
# 45      NO     NO

# %%
t = pd.crosstab(drugs.Alcohol,drugs.Opiods, margins=False)
t = t.sort_index(axis = 1, ascending=True)
t
# Out:
# Opiods   NO  YES
# Alcohol
# NO       16    3
# YES      20    7

# %%
est = (7*16)/(20*3)
print(est)
# Out:
# 1.8666666666666667

# %%
OR_CI(16,3,20,7,0.01)
# Out:
# (0.2586755270556728, 13.47032896426461)

# %%
drugs2 = drugs[["Alcohol", "Marijuana"]]

# %%
t2 = pd.crosstab(drugs2.Marijuana,drugs2.Alcohol, margins=False)
t2 = t2.sort_index(axis = 1, ascending=True)
t2
# Out:
# Alcohol    NO  YES
# Marijuana
# NO         17   23
# YES         2    4

# %%
ss.fisher_exact(t2)
# Out:
# (1.4782608695652173, 1.0)

# %%
drug3 = drugs[["Opiods", "Marijuana"]]

# %%
drug3
# Out:
#    Opiods Marijuana
# 0      NO       YES
# 1      NO        NO
# 2      NO        NO
# 3      NO        NO
# 4      NO        NO
# 5     YES       YES
# 6      NO        NO
# 7      NO        NO
# 8     YES        NO
# 9      NO        NO
# 10     NO        NO
# 11     NO        NO
# 12     NO        NO
# 13    YES        NO
# 14     NO        NO
# 15     NO        NO
# 16    YES        NO
# 17     NO        NO
# 18     NO        NO
# 19    YES        NO
# 20    YES        NO
# 21    YES       YES
# 22     NO        NO
# 23     NO        NO
# 24     NO        NO
# 25     NO        NO
# 26     NO        NO
# 27     NO        NO
# 28     NO        NO
# 29     NO        NO
# 30     NO        NO
# 31     NO        NO
# 32     NO       YES
# 33     NO        NO
# 34     NO       YES
# 35     NO        NO
# 36     NO        NO
# 37    YES        NO
# 38     NO        NO
# 39    YES        NO
# 40     NO        NO
# 41     NO        NO
# 42    YES        NO
# 43     NO       YES
# 44     NO        NO
# 45     NO        NO

# %%
t3 = pd.crosstab(drug3.Marijuana,drug3.Opiods, margins=False)
t3 = t3.sort_values(by=['Opiods','YES'], axis=1, ascending=True)
t3
# categorical / sort values
# Out:
# Opiods     NO  YES
# Marijuana
# NO         32    8
# YES         4    2

# %%
ss.fisher_exact(t3)
# Out:
# (2.0, 0.5975239833288131)

# %%
OR_CI(32,8,4,2,0.05)
# Out:
# (0.30953535997359904, 12.922594692707055)

# %%
est3 = (32*2)/(8*4)
print(est3)
# Out:
# 2.0

# %%
# 17->20
OR_CI(20,18,25,137,0.05)
# Out:
# (2.829741326882737, 13.101751580267642)

# %%
n = [(20, 18),(25,137)]

# %%
n
# Out:
# [(20, 18), (25, 137)]

# %%
i = (20/38)/(25/162)
i
# Out:
# 3.4105263157894736

# %%
esti = (20*137)/(18*25)
print(esti)
# Out:
# 6.088888888888889
